# %%
'''
这是多行注释标记
'''

x = 3
y = 3
print(id(x))
print(id(y))
x = 4
print(id(x))
# Out:
# 140727007775224
# 140727007775224
# 140727007775256

# %%
# print(15151515151515151515 * 33333333333333333333)
result = 2016 ** 2016
print(result % 100 // 10)
# Out:
# 1

# %%
print(23+3)
print(23 > 3)
print('23' + '3')
print(23 / 3)
print(23 // 3)
print(23 % 3)
print(23 ** 3)
# Out:
# 26
# True
# 233
# 7.666666666666667
# 7
# 2
# 12167

# %%
s1 = "programming"
s2 = "language"
print(s1[1])
print(s1[:4]) # 不包括4
print(s1[0] + s2[1:3])
print(s1.capitalize() + ' ' + s2.upper()) # 首字母大写
print(s1.count('r'), s1.find('r'), s1.rfind('r'))
s3 = s2.join('--') # 用s2连接--中的字符
print(s3)
s4 = '-'.join(s2) # 用-连接s2中的字符
print(s4)
L1 = s4.split("-") # 用-分割s4, 返回一个列表
print(L1)
print(3 * (s2[:2] + ' '))
print("Python" + s2.rjust(10)) # 返回一个右对齐的字符串
# Out:
# r
# prog
# pan
# Programming LANGUAGE
# 2 1 4
# -language-
# l-a-n-g-u-a-g-e
# ['l', 'a', 'n', 'g', 'u', 'a', 'g', 'e']
# la la la
# Python  language

# %%
from pprint import *
keywords = ['if','else','for','while','True']
print()
for kw in keywords:
    help(kw)
# Out:
# The "if" statement
# ******************
#
# The "if" statement is used for conditional execution:
#
#    if_stmt ::= "if" assignment_expression ":" suite
#                ("elif" assignment_expression ":" suite)*
#                ["else" ":" suite]
#
# It selects exactly one of the suites by evaluating the expressions one
# by one until one is found to be true (see section Boolean operations
# for the definition of true and false); then that suite is executed
# (and no other part of the "if" statement is executed or evaluated).
# If all expressions are false, the suite of the "else" clause, if
# present, is executed.
#
# Related help topics: TRUTHVALUE
#
# The "if" statement
# ******************
#
# The "if" statement is used for conditional execution:
#
#    if_stmt ::= "if" assignment_expression ":" suite
#                ("elif" assignment_expression ":" suite)*
#                ["else" ":" suite]
#
# It selects exactly one of the suites by evaluating the expressions one
# ...

# %%
print(ord('a') - ord('c'))
print(ord("汉"))
# Out:
# -2
# 27721

# %%
import math
print(math.log(2.7))
print(math.log(100, 10))
print(math.log10(10))
print(math.log2(256))
# Out:
# 0.9932517730102834
# 2.0
# 1.0
# 8.0

# %%
import random
a = [random.randint(1, 100) for i in range(100)]
print(a)
print(math.sqrt(100))
print(max(a))
print(min(a))
print(sum(a))
print(sum(a) / len(a))
# Out:
# [7, 98, 99, 56, 63, 52, 22, 63, 51, 17, 60, 69, 81, 85, 5, 98, 58, 13, 34, 40, 20, 23, 15, 16, 38, 22, 52, 83, 1, 89, 90, 90, 36, 60, 64, 38, 84, 88, 74, 6, 14, 87, 86, 12, 5, 85, 99, 37, 27, 91, 16, 66, 82, 29, 51, 7, 3, 80, 60, 73, 23, 27, 87, 88, 39, 8, 60, 90, 54, 33, 1, 10, 22, 13, 98, 78, 74, 53, 91, 44, 8, 60, 34, 52, 72, 61, 13, 38, 9, 52, 67, 69, 73, 20, 25, 90, 47, 78, 84, 69]
# 10.0
# 99
# 1
# 5084
# 50.84

# %%
word = "helxo"
reversed_word = word[::-1]
print(reversed_word)
# Out:
# oxleh

# %%
import random
x = [random.randint(0, 100) for i in range(1000)]
# 统计每个元素出现的次数
s = set(x)
for i in s:
    print(i, x.count(i))
# Out:
# 0 11
# 1 12
# 2 12
# 3 9
# 4 10
# 5 7
# 6 12
# 7 8
# 8 8
# 9 10
# 10 12
# 11 11
# 12 11
# 13 10
# 14 14
# 15 8
# 16 13
# 17 7
# 18 13
# 19 8
# 20 10
# 21 15
# 22 8
# 23 13
# 24 14
# 25 14
# 26 8
# 27 8
# 28 14
# 29 7
# 30 12
# 31 12
# 32 7
# 33 13
# 34 5
# 35 9
# 36 12
# 37 8
# 38 7
# 40 6
# 41 11
# 42 10
# 43 9
# 44 12
# 45 16
# 46 13
# 47 5
# 48 8
# 49 12
# 50 8
# 51 10
# 52 2
# 53 9
# 54 9
# 55 20
# 56 9
# 57 10
# 58 8
# 59 9
# 60 9
# 61 14
# 62 5
# 63 8
# 64 6
# 65 13
# 66 8
# 67 10
# 68 15
# 69 14
# 70 11
# 71 4
# 72 8
# 73 11
# 74 14
# 75 8
# 76 13
# 77 7
# 78 6
# 79 8
# 80 10
# 81 15
# 82 10
# 83 14
# 84 12
# 85 10
# 86 11
# 87 13
# 88 9
# 89 8
# 90 10
# 91 12
# 92 8
# 93 10
# 94 4
# 95 6
# 96 6
# 97 10
# 98 13
# 99 9
# 100 10

# %%
x = input('Please input a list:')
x = list(map(int, x.split()))
print(x)
# Out:
# [1, 2, 3, 4, 5]

# %%
x = input('Please input a list:')
x = list(map(int, x.split()))
y = input('Please input 2 index')
y = list(map(int, y.split()))
print(x[y[0]:y[1]+1])
# Out:
# [3, 4, 5, 6]

# %%
d = {1:'a', 2:'b', 3:'c', 4:'d', '666':'this is str', 666: 'this is number'}
v = input('Please input a key:')
v = eval(v)
print(d.get(v,'您输入的的键不存在'))
# Out:
# this is number

# %%
import random

'''
列表推导式格式：expression for varible in iterable
expression是每个元素都要执行的操作，varible是每次迭代中使用的变量，iterable是可迭代的序列
''' 
# x = [random.randint(0,1000) for i in range(20)]
x = [484, 616, 839, 523, 477, 892, 601, 96, 766, 848, 186, 388, 967, 730, 248, 215, 727, 998, 705, 565]
print(x)

x[:10] = sorted(x[:10])
x[-10:] = sorted(x[-10:], reverse = True)
print(x)
# Out:
# [484, 616, 839, 523, 477, 892, 601, 96, 766, 848, 186, 388, 967, 730, 248, 215, 727, 998, 705, 565]
# [96, 477, 484, 523, 601, 616, 766, 839, 848, 892, 998, 967, 730, 727, 705, 565, 388, 248, 215, 186]

# %%
import random
x = [random.randint(0,100) for i in range(20)]
print(x)

x[::2] = sorted(x[::2], reverse = True)
for pair in enumerate(x):
    print(pair)
# Out:
# [59, 46, 81, 49, 34, 54, 17, 26, 19, 100, 26, 69, 55, 30, 58, 70, 69, 36, 88, 10]
# (0, 88)
# (1, 46)
# (2, 81)
# (3, 49)
# (4, 69)
# (5, 54)
# (6, 59)
# (7, 26)
# (8, 58)
# (9, 100)
# (10, 55)
# (11, 69)
# (12, 34)
# (13, 30)
# (14, 26)
# (15, 70)
# (16, 19)
# (17, 36)
# (18, 17)
# (19, 10)

# %%
x = [1,2,2,2,3,3,4,4,4,4,5]
y = set(x)
print(y)
# Out:
# {1, 2, 3, 4, 5}

# %%
x = input('Please input a number(number < 1000):')
x = eval(x)
t = x
i = 2
factors = []
while True:
    if t == 1:
        break;
    if t % i == 0:
        factors.append(i)
        t /= i
    else:
    	i += 1
print(x, '=', '*'.join(map(str, factors)))
# Out:
# 100 = 2x2x5x5

# %%
print(sum([i for i in range(1, 100) if i % 2 == 1])) # 列表推导式
print(sum(list(range(1,100))[::2])) # 切片操作
# Out:
# 2500
# 2500

# %%
from itertools import permutations
number = [1,2,3,4]
primes = set()
for r in range(1, 5):
    for it in permutations(number, r):
        # it = int(''.join(map(str, it)))
        print(it)

# %%
from itertools import permutations
from math import sqrt
def is_prime(x):
    if x < 2:
        return False
    for i in range(2, int(sqrt(x) + 1)):
        if x % i == 0:
            return False;
    return True
numbers = [1,2,3,4]
primes = set()
for r in range(1, 5):
    for it in permutations(numbers, r): # 生成长度分别为1，2，3，4的1，2，3，4的全排列
        t = int(''.join(map(str, it)))
        if is_prime(t):
            primes.add(t)
for prime in sorted(primes):
    print(prime)
# Out:
# 2
# 3
# 13
# 23
# 31
# 41
# 43
# 241
# 421
# 431
# 1423
# 2143
# 2341
# 4231

# %%
x = input('Please input x:')
x = eval(x)
if 0 <= x < 5:
    print(x)
elif 5 <= x < 10:
    print(3 * x - 5)
elif 10 <= x < 20:
    print(0.5 * x - 2)
else:
    print(0)
# Out:
# 4.5

# %%
import re
x = "thIs am a strIng, aIm prIorItIes"
result = re.sub(r'\BI\B', 'i', x) # 要匹配的正则表达式、替换后的内容、原始字符串
print(result)
# Out:
# this am a string, aim priorities
